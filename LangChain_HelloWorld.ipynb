# %% [markdown]
# <a href="https://colab.research.google.com/github/SarwatMajeed24/PIAIC/blob/main/LangChain_HelloWorld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -Uq langchain langchain-google-genai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 15.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.6/411.6 kB 23.6 MB/s eta 0:00:00

# %%
import langchain_google_genai as genai

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
from google.colab import userdata
GOOGLE_API_KEY = userdata.get("GOOGLE_API_KEY")

# %%
model : ChatGoogleGenerativeAI = ChatGoogleGenerativeAI(
      model = "gemini-1.5-flash",
      api_key = GOOGLE_API_KEY
)

# %%
res = model.invoke("what is Agentic Ai")
print(res.content)
# Out:
# Agentic AI refers to artificial intelligence systems that are capable of independent action and goal-directed behavior in the real world.  Unlike reactive AI, which simply responds to stimuli, or deliberate AI, which plans actions based on a given goal, an agentic AI system *itself* identifies goals, plans how to achieve them, and executes those plans autonomously.  This involves several key characteristics:
#
# * **Autonomy:**  Agentic AI systems can operate without constant human intervention. They can make decisions and take actions based on their own internal models and perceptions of the environment.
#
# * **Goal-directedness:** They possess internal motivations or objectives that drive their actions.  These goals can be pre-programmed, learned through interaction, or a combination of both.
#
# * **Proactiveness:**  Rather than just reacting to events, agentic AI systems actively seek out opportunities and initiate actions to achieve their goals.
#
# ...

# %%
res2 = model.invoke("what is Rag")
print(res2.content)
# Out:
# "Rag" can refer to several things, depending on the context:
#
# * **A torn piece of cloth:** This is the most common meaning.  A rag is a small piece of old cloth, often used for cleaning.
#
# * **A type of music:**  Specifically, a ragtime composition.  Ragtime is a style of early 20th-century American music characterized by its syncopated rhythm.
#
# * **A slang term for a person:**  This is less common and often derogatory, implying someone is unimportant or worthless.
#
# * **Short for "ragout":**  A ragout is a type of stew.
#
#
# To understand what "rag" means, you need to consider the context in which it's used.

# %%
res3 = model.invoke("what is meant by LangChain")
print(res3.content)
# Out:
# LangChain is a framework for developing applications powered by large language models (LLMs).  It's designed to make it easier to build more complex and useful applications than you could with just the LLM API alone.  Instead of just sending a prompt and receiving a response, LangChain allows you to:
#
# * **Chain multiple LLMs together:**  You can connect the output of one LLM to the input of another, creating more sophisticated workflows and problem-solving capabilities.
#
# * **Integrate LLMs with other sources of data:**  Connect your LLMs to databases, APIs, and other data sources so the LLM can access and process information beyond its training data.  This allows for applications that are grounded in real-world facts and up-to-date information.
#
# ...
